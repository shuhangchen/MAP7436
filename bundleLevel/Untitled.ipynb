-- %%
Plot = require 'itorch.Plot'
function f(x)
    local numera = torch.cmul(torch.cmul(torch.pow(x,2) - 4, x + 3), x - 4)
    local denumera = torch.cmul(x-2, torch.pow(x,2) - 2)
    return torch.cdiv(numera, denumera)
    end

x = torch.linspace(-2, 2)
--y = f(x)
plot=Plot()
plot:line(x, torch.sin(x),'red' ,'Sinus Wave')
plot:draw()
-- Out:
-- /Users/shuhang/torch/install/share/lua/5.1/itorch/Plot.lua:696: Cannot serialise number: must not be NaN or Infinity
-- stack traceback:
-- 	[C]: in function 'encode'
-- 	/Users/shuhang/torch/install/share/lua/5.1/itorch/Plot.lua:696: in function 'encodeAllModels'
-- 	/Users/shuhang/torch/install/share/lua/5.1/itorch/Plot.lua:802: in function 'toTemplate'
-- 	/Users/shuhang/torch/install/share/lua/5.1/itorch/Plot.lua:818: in function 'draw'
-- 	[string "Plot = require 'itorch.Plot'..."]:12: in main chunk
-- 	[C]: in function 'xpcall'
-- 	/Users/shuhang/torch/install/share/lua/5.1/itorch/main.lua:210: in function </Users/shuhang/torch/install/share/lua/5.1/itorch/main.lua:174>
-- 	/Users/shuhang/torch/install/share/lua/5.1/lzmq/poller.lua:75: in function 'poll'
-- 	...s/shuhang/torch/install/share/lua/5.1/lzmq/impl/loop.lua:307: in function 'poll'
-- 	...s/shuhang/torch/install/share/lua/5.1/lzmq/impl/loop.lua:325: in function 'sleep_ex'
-- ...

-- %%
y:eq(Infinity)
-- Out:
-- [string "local f = function() return y:eq(Infinity) en..."]:1: invalid arguments: DoubleTensor nil
-- expected arguments: [*ByteTensor*] DoubleTensor double | *DoubleTensor* DoubleTensor double | [*ByteTensor*] DoubleTensor DoubleTensor | *DoubleTensor* DoubleTensor DoubleTensor
-- stack traceback:
-- 	[C]: in function 'f'
-- 	[string "local f = function() return y:eq(Infinity) en..."]:1: in main chunk
-- 	[C]: in function 'xpcall'
-- 	/Users/shuhang/torch/install/share/lua/5.1/itorch/main.lua:210: in function </Users/shuhang/torch/install/share/lua/5.1/itorch/main.lua:174>
-- 	/Users/shuhang/torch/install/share/lua/5.1/lzmq/poller.lua:75: in function 'poll'
-- 	...s/shuhang/torch/install/share/lua/5.1/lzmq/impl/loop.lua:307: in function 'poll'
-- 	...s/shuhang/torch/install/share/lua/5.1/lzmq/impl/loop.lua:325: in function 'sleep_ex'
-- 	...s/shuhang/torch/install/share/lua/5.1/lzmq/impl/loop.lua:370: in function 'start'
-- ...

-- %%
y
-- Out:
-- -8.000000
-- -7.996755
-- -7.993510
-- -7.990265
-- -7.987019
-- -7.983774
-- -7.980529
-- -7.977283
-- -7.974037
-- -7.970791
-- -7.967545
-- -7.964299
-- -7.961053
-- -7.957806
-- -7.954560
-- -7.951313
-- -7.948067
-- -7.944820
-- -7.941573
-- -7.938326
-- -7.935079
-- -7.931831
-- -7.928584
-- -7.925336
-- -7.922089
-- -7.918841
-- -7.915593
-- -7.912345
-- -7.909097
-- -7.905849
-- -7.902600
-- -7.899352
-- -7.896103
-- -7.892855
-- -7.889606
-- -7.886357
-- -7.883108
-- -7.879859
-- -7.876609
-- -7.873360
-- -7.870110
-- -7.866861
-- -7.863611
-- -7.860361
-- -7.857111
-- -7.853861
-- -7.850610
-- -7.847360
-- -7.844110
-- -7.840859
-- -7.837608
-- -7.834357
-- -7.831106
-- -7.827855
-- -7.824604
-- -7.821353
-- -7.818101
-- -7.814850
-- -7.811598
-- -7.808346
-- -7.805094
-- -7.801842
-- -7.798590
-- -7.795338
-- -7.792085
-- -7.788833
-- -7.785580
-- -7.782327
-- -7.779074
-- -7.775821
-- -7.772568
-- -7.769315
-- -7.766061
-- -7.762808
-- -7.759554
-- -7.756300
-- ...
